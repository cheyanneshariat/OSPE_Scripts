# %%
import numpy as np
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'retina'
plt.rc('text', usetex=False)
plt.rc('font', family='serif')

import PhenomA as pa
import LISA as li
import WaveformTools as wt

# %% [markdown]
# # Setup LISA object, load sky & polarization averaged transfer function, plot sensitivity curve
#
#
# ### LISA object options
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Tobs, default=4 yr ---- example: lisa = li.LISA(Tobs=li.YEAR)
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Larm, default=2.5e9 (meters)
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; NC,   default=2 (number of data channels, 1 or 2)

# %%
# create LISA object
lisa = li.LISA() 
lisa.ecc = 0.1

# Plot LISA's sensitivity curve
f  = np.logspace(np.log10(1.0e-5), np.log10(1.0e0), 1000)
Sn = lisa.Sn(f)
li.PlotSensitivityCurve(f, Sn) # provide additional argument, e.g. 'SensitivityCurve.pdf', to save figure

# %% [markdown]
# # Setup Binary Parameters and create a binary object

# %%
m1 = 0.5e6*pa.TSUN 
m2 = 0.5e6*pa.TSUN
z = 3.0
T_merge = 1.*li.YEAR

binary = wt.Binary(m1, m2, z=z,)
binary.T_merge = T_merge
binary.SetFreqBounds(lisa)

freqs, X_char = binary.CalcStrain(lisa)
snr = binary.CalcSNR(freqs, X_char, lisa)
print("\nSNR........ {}".format(snr))
binary.PlotStrain(freqs, X_char, lisa)
# Out:
# Redshift provided.
# 	Luminosity Distance........... 25924.151861680206 Mpc
#
# SNR........ 2624.394756678925

# %% [markdown]
# ## Specify a sky location

# %%
m1 = 0.5e6*pa.TSUN 
m2 = 0.5e6*pa.TSUN
z = 3.0
T_merge = 1.*li.YEAR

binary = wt.Binary(m1, m2, z=z)
binary.T_merge = T_merge
binary.SetFreqBounds(lisa)

theta = 0.5
phi = 2.3

freqs, X_char = binary.CalcStrain(lisa, theta, phi)
snr = binary.CalcSNR(freqs, X_char, lisa)
print("\nSNR........ {}".format(snr))
binary.PlotStrain(freqs, X_char, lisa)
# Out:
# Redshift provided.
# 	Luminosity Distance........... 25924.151861680206 Mpc
#
# SNR........ 3098.265241298385

# %% [markdown]
# ## Choose an inclination as the third parameter

# %%
m1 = 0.5e6*pa.TSUN 
m2 = 0.5e6*pa.TSUN
z = 3.0
T_merge = 1.*li.YEAR

binary = wt.Binary(m1, m2, z=z)
binary.T_merge = T_merge
binary.SetFreqBounds(lisa)

theta = 0.5
phi = 2.3
iota = 1.0

freqs, X_char = binary.CalcStrain(lisa, theta, phi, iota)
snr = binary.CalcSNR(freqs, X_char, lisa)
print("\nSNR........ {}".format(snr))
binary.PlotStrain(freqs, X_char, lisa)
# Out:
# Redshift provided.
# 	Luminosity Distance........... 25924.151861680206 Mpc
#
# SNR........ 2899.8625598061917

# %% [markdown]
# # LIGO Binary

# %%
m1 = 36.0*pa.TSUN 
m2 = 29.0*pa.TSUN
Dl = 410.*wt.MPC
T_merge = 5.*li.YEAR

binary = wt.Binary(m1, m2, Dl=Dl)
binary.T_merge = T_merge
binary.SetFreqBounds(lisa)

freqs, X_char = binary.CalcStrain(lisa)
snr = binary.CalcSNR(freqs, X_char, lisa)
print("\nSNR........ {}".format(snr))
binary.PlotStrain(freqs, X_char, lisa)
# Out:
# Luminosity Distance provided.
# 	redshift........... 0.08891326018535295
#
# SNR........ 4.666592661632494

# %%
m1 = 36.0*pa.TSUN 
m2 = 29.0*pa.TSUN
Dl = 410.*wt.MPC
T_merge = 5.*li.YEAR

binary = wt.Binary(m1, m2, Dl=Dl)
binary.T_merge = T_merge
binary.SetFreqBounds(lisa)

freqs, X_char = binary.CalcStrain(lisa, 1.1, 1.5)
snr = binary.CalcSNR(freqs, X_char, lisa)
print("\nSNR........ {}".format(snr))
binary.PlotStrain(freqs, X_char, lisa)
# Out:
# Luminosity Distance provided.
# 	redshift........... 0.08891326018535295
#
# SNR........ 4.657418843033033

# %% [markdown]
# # Galactic Binary

# %%
binary.Figure_Type
# Out:
# 'track'

# %%
m1 = 0.50*pa.TSUN 
m2 = 0.50*pa.TSUN
Dl = 0.2e-3*wt.MPC
T_merge = 5.*li.YEAR
lisa.Tobs = 4.*li.YEAR
f_start  = 2.6e-5
f_end    = 1e-1

binary = wt.Binary(m1, m2, Dl=Dl)
binary.T_merge = T_merge
binary.f_start = 1e-5
binary.f_end   = 1e-1
binary.SetFreqBounds(lisa)

binary.Figure_Type = 'track'
freqs, X_char = binary.CalcStrain(lisa)
snr = binary.CalcSNR(f = np.logspace(np.log10(1.0e-5), np.log10(1.0e0), 1000), X_char = X_char, lisa = lisa)
print("\nSNR........ {}".format(snr))
binary.PlotStrain(freqs = np.logspace(np.log10(1.0e-5), np.log10(1.0e0), 1000), X_char=X_char, lisa=lisa)
# Out:
# Luminosity Distance provided.
# 	redshift........... 4.623471017600289e-08
#
# SNR........ 1.5570019560435237e-05

# %%
m1 = 0.50*pa.TSUN 
m2 = 0.25*pa.TSUN
Dl = 1.0e-3*wt.MPC
f_start  = 2.6e-3
f_end=1e-1
binary = wt.Binary(m1, m2, Dl=Dl)
binary.f_start = f_start
binary.f_end = f_end
binary.SetFreqBounds(lisa)

freqs, X_char = binary.CalcStrain(lisa, 1.1, 1.5)
snr = binary.CalcSNR(freqs, X_char, lisa)
print("\nSNR........ {}".format(snr))
binary.PlotStrain(freqs, X_char, lisa)
# Out:
# Luminosity Distance provided.
# 	redshift........... 2.3117351864949706e-07
#
# SNR........ 212.451466380436
