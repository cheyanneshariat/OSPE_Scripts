# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from astropy import units as u
from astroquery.gaia import Gaia

# %%
Gaia.login()
# Out:
# INFO: Login to gaia TAP server [astroquery.gaia.core]
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 Gaia.login()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/astroquery/gaia/core.py:99, in GaiaClass.login(self, user, password, credentials_file, verbose)
#      97 try:
#      98     log.info("Login to gaia TAP server")
# ---> 99     TapPlus.login(self, user=user, password=password,
#     100                   credentials_file=credentials_file,
#     101                   verbose=verbose)
#     102 except HTTPError as err:
#     103     log.error("Error logging in TAP server")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/astroquery/utils/tap/core.py:2031, in TapPlus.login(self, user, password, credentials_file, verbose)
#    2029 self.__user = str(user)
# ...

# %%
dist_lim_pc = 10* u.Parcsec

query = f"SELECT source_id, distance_gspphot, distance_gspphot_lower, distance_gspphot_upper,distance_msc, radius_gspphot,radius_gspphot_lower,radius_gspphot_upper,mass_flame,mass_flame_lower,mass_flame_upper, \
    age_flame,age_flame_lower,age_flame_upper, evolstage_flame, classprob_dsc_specmod_star, classprob_dsc_specmod_binarystar,classprob_dsc_combmod_whitedwarf,classprob_dsc_combmod_star, teff_gspspec,logg_gspspec, \
FROM gaiadr3.gaia_source \
WHERE distance_gspphot <= {dist_lim_pc.value}\
AND ruwe >1.4"

job     = Gaia.launch_job_async(query)
results = job.get_results()
print(f'Table size (rows): {len(results)}')

results['distance_lightyear'] = results['distance_gspphot'].to(u.lightyear)
results['radial_velocity_ms'] = results['radial_velocity'].to(u.meter/u.second)
results
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# Cell In[9], line 8
#       1 dist_lim_pc = 10* u.Parcsec
#       3 query = f"SELECT source_id, ra, dec, parallax, distance_gspphot, teff_gspphot, azero_gspphot, phot_g_mean_mag, radial_velocity \
#       4 FROM gaiadr3.gaia_source \
#       5 WHERE distance_gspphot <= {dist_lim_pc.value}\
#       6 AND ruwe >1.4"
# ----> 8 job     = Gaia.launch_job_async(query)
#       9 results = job.get_results()
#      10 print(f'Table size (rows): {len(results)}')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/astroquery/gaia/core.py:903, in GaiaClass.launch_job_async(self, query, name, output_file, output_format, verbose, dump_to_file, background, upload_resource, upload_table_name, autorun)
#     862 def launch_job_async(self, query, name=None, output_file=None,
# ...
